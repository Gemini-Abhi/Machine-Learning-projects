# %% [markdown]
# ## Exploring Global Terrorism Trends: A Geospatial Analysis

# %% [markdown]
# ***Over the years, the world has encountered a dual challenge, grappling with both natural and man-made calamities. A recent survey reveals that annually, an alarming 218 million individuals bear the brunt of these disasters, leading to a devastating loss of around 68,000 lives. Despite the consistent occurrence of natural disasters like earthquakes and volcanoes, a troubling pattern unfolds globally — a continuous rise in the frequency of terrorist activities over the years.***

# %% [markdown]
# ### Project Goals:
# ***The primary aim of this notebook is to delve into the intricate world of global terrorism. Through the use of interactive plots and animations, we aim to make the exploration of this complex issue both accessible and informative.***

# %% [markdown]
# ### This analysis seeks to address the following inquiries:
#
# How has the incidence of terrorist activities evolved over the years, and are there specific regions exhibiting variations from global averages?
#
# What is the frequency of successful attacks?
#
# What are the predominant methods employed in these attacks, and do they vary across regions or over time?

# %% [markdown]
# ### Steps tp be Followed:
# ***1.Data Acquisition***
#
# ***2.Data Preprocessing***
#
# ***3.Model Selection***
#
# ***4.Model Training & Evaluation***
#
# ***Model Comparison***

# %% [markdown]
# ### 1.Data Acquisition & Data Understanding

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows=200

# %%
df=pd.read_csv(r"E:\Data Analyst Journey\Projects\Terrorism Project\globalterrorismdb_0718dist.csv",encoding = 'ISO-8859-1')
df.head(10)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_43868\146814947.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"E:\Data Analyst Journey\Projects\Terrorism Project\globalterrorismdb_0718dist.csv",encoding = 'ISO-8859-1')
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# The shape of the dataset.
df.shape
# Out:
# (181691, 135)

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
#creating a backup
df1=df.copy()
df1.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# 7  197001020002   1970       1     2        NaN         0        NaN      217
# 8  197001020003   1970       1     2        NaN         0        NaN      217
# 9  197001030001   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# ...

# %% [markdown]
# ##

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Data Cleaning

# %%
df1.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df1.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
#Showing all column names
for col in df1.columns:
    print(col)
# Out:
# eventid
# iyear
# imonth
# iday
# approxdate
# extended
# resolution
# country
# country_txt
# region
# region_txt
# provstate
# city
# latitude
# longitude
# specificity
# vicinity
# location
# summary
# crit1
# crit2
# crit3
# doubtterr
# alternative
# alternative_txt
# multiple
# success
# suicide
# attacktype1
# attacktype1_txt
# attacktype2
# attacktype2_txt
# attacktype3
# attacktype3_txt
# targtype1
# targtype1_txt
# targsubtype1
# targsubtype1_txt
# corp1
# target1
# natlty1
# natlty1_txt
# targtype2
# targtype2_txt
# targsubtype2
# targsubtype2_txt
# corp2
# target2
# natlty2
# natlty2_txt
# targtype3
# targtype3_txt
# targsubtype3
# targsubtype3_txt
# corp3
# target3
# natlty3
# natlty3_txt
# gname
# gsubname
# gname2
# gsubname2
# gname3
# gsubname3
# motive
# guncertain1
# guncertain2
# guncertain3
# individual
# nperps
# nperpcap
# claimed
# claimmode
# claimmode_txt
# claim2
# claimmode2
# claimmode2_txt
# claim3
# claimmode3
# claimmode3_txt
# compclaim
# weaptype1
# ...

# %%
#checking for datatypes of each feature
df1.dtypes
# Out:
# eventid                 int64
# iyear                   int64
# imonth                  int64
# iday                    int64
# approxdate             object
# extended                int64
# resolution             object
# country                 int64
# country_txt            object
# region                  int64
# region_txt             object
# provstate              object
# city                   object
# latitude              float64
# longitude             float64
# specificity           float64
# vicinity                int64
# location               object
# summary                object
# crit1                   int64
# crit2                   int64
# crit3                   int64
# doubtterr             float64
# alternative           float64
# alternative_txt        object
# multiple              float64
# success                 int64
# suicide                 int64
# attacktype1             int64
# attacktype1_txt        object
# attacktype2           float64
# ...

# %%
#Now renaming the column names 
df1.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country',
                    'provstate':'State','region_txt':'Region','attacktype1_txt':'AttackType',
                    'target1':'Target','nkill':'killed','nwound': 'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                     'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %%
df1.columns
# Out:
# Index(['eventid', 'Year', 'Month', 'Day', 'approxdate', 'extended',
#        'resolution', 'country', 'Country', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# As we have many columns, we take the columns that are necessary for analysis
df2 = df1[['eventid','Year','Month','Day','Country','Region','State','city','latitude','longitude','AttackType','killed','Wounded',
            'Target','Summary','Group','Target_type','Weapon_type','Motive','success']]

# %%
df2.head(5)
# Out:
#         eventid  Year  Month  Day             Country  \
# 0  197000000001  1970      7    2  Dominican Republic
# 1  197000000002  1970      0    0              Mexico
# 2  197001000001  1970      1    0         Philippines
# 3  197001000002  1970      1    0              Greece
# 4  197001000003  1970      1    0               Japan
#
#                         Region    State           city   latitude   longitude  \
# 0  Central America & Caribbean      NaN  Santo Domingo  18.456792  -69.951164
# 1                North America  Federal    Mexico city  19.371887  -99.086624
# 2               Southeast Asia   Tarlac        Unknown  15.478598  120.599741
# 3               Western Europe   Attica         Athens  37.997490   23.762728
# 4                    East Asia  Fukouka        Fukouka  33.580412  130.396361
#
#                        AttackType  killed  Wounded                   Target  \
# 0                   Assassination     1.0      0.0             Julio Guzman
# ...

# %%
# Combining two columns "Killed" and "wounded" to a single column "Casualties"
df2["Casualties"]=df2["killed"]+df2["Wounded"]
df2.head(5)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_43868\3084081155.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Casualties"]=df2["killed"]+df2["Wounded"]
#         eventid  Year  Month  Day             Country  \
# 0  197000000001  1970      7    2  Dominican Republic
# 1  197000000002  1970      0    0              Mexico
# 2  197001000001  1970      1    0         Philippines
# 3  197001000002  1970      1    0              Greece
# 4  197001000003  1970      1    0               Japan
#
#                         Region    State           city   latitude   longitude  \
# 0  Central America & Caribbean      NaN  Santo Domingo  18.456792  -69.951164
# 1                North America  Federal    Mexico city  19.371887  -99.086624
# ...

# %%
#Checking the final Shape
df2.shape
# Out:
# (181691, 21)

# %%
# Checking for percent of Null values in the Dataset
round((df2.isna().sum()/len(df2)) * 100,2)
# Out:
# eventid         0.00
# Year            0.00
# Month           0.00
# Day             0.00
# Country         0.00
# Region          0.00
# State           0.23
# city            0.24
# latitude        2.51
# longitude       2.51
# AttackType      0.00
# killed          5.68
# Wounded         8.98
# Target          0.35
# Summary        36.40
# Group           0.00
# Target_type     0.00
# Weapon_type     0.00
# Motive         72.17
# success         0.00
# Casualties      9.29
# dtype: float64

# %% [markdown]
# ***From above we can see that the highest number of null values are present in "Motive" column,approx 72% . Secondly "Summary" column is having 36.4 % null values.***

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Number of Terrorist Activity Each year

# %%
year_attacks = df2.groupby('Year').size().reset_index(name='count')
sns.lineplot(x='Year',y='count',data=year_attacks,color='blue')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.show()

# %%
plt.subplots(figsize=(15,6))
sns.countplot(x='Year',data=df2,palette='inferno')
plt.xticks(rotation=90)
plt.title("Number of Terrorist Activities Each year")
# Out:
# Text(0.5, 1.0, 'Number of Terrorist Activities Each year')

# %% [markdown]
# ***It should be noted that the number of terrorist attacks has been increasing over time; after 1997, there was a drop in the chart indicating fewer assaults, but it peaks in 2014.After 2014, the graph shows a decrease, indicating that the government's efforts have yielded effect and that there is hope for less terrorism.***

# %% [markdown]
# ### Terrorist Attacks Trends in Regions

# %%
Region_attacks = df2.groupby(['Year','Region']).size().reset_index(name='Count')
Region_attacks
plt.subplots(figsize=(15,6))
sns.lineplot(x='Year',y='Count',hue='Region',data=Region_attacks)
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
plt.subplots(figsize=(15,6))
sns.countplot(x='Region',data=df2,palette='magma',order=df2['Region'].value_counts().index)
plt.xticks(rotation=80)
plt.title('Number Of Terrorist Activities By Region')
plt.show()

# %% [markdown]
# ***The rise of terrorism in the Middle East and North African region is more remarkable compared to others. Reasons could be political instability, social and economic factors, or regional conflicts. South Asia has also seen increasing terrorism throughout the years. In contrast, Central Asia has comparatively lower terrorism rates.***

# %% [markdown]
# ## Top 10 Affected Countries

# %%
top_countries=df2['Country'].value_counts()[:10].reset_index(name='count')
plt.subplots(figsize=(14,6))

plt.title('Top 10 Affected Countries')

sns.barplot(data=top_countries,x='Country',y=top_countries['count'],palette='magma',order=top_countries['Country'])
# Out:
# <Axes: title={'center': 'Top 10 Affected Countries'}, xlabel='Country', ylabel='count'>

# %% [markdown]
# ***The graph highlights five countries most affected by terrorism:***
#
# 1.Iraq
#
# 2.Pakistan
#
# 3.Afghanistan
#
# 4.India
#
# 5.Colombia
#
# ***These nations face significant challenges related to terrorism, requiring ongoing efforts to ensure the safety and security of their populations and regional stability.***

# %% [markdown]
# ### Top 10 affected cities.

# %%
top_cities = df2['city'].value_counts()[:10].reset_index(name='Count')
top_cities
# Out:
#            city  Count
# 0       Unknown   9775
# 1       Baghdad   7589
# 2       Karachi   2652
# 3          Lima   2359
# 4         Mosul   2265
# 5       Belfast   2171
# 6      Santiago   1621
# 7     Mogadishu   1581
# 8  San Salvador   1558
# 9      Istanbul   1048

# %%
plt.subplots(figsize=(13,6))
plt.title("Top 10 Affected Cities")
sns.barplot(data=top_cities,x='city',y='Count',palette='magma')
# Out:
# <Axes: title={'center': 'Top 10 Affected Cities'}, xlabel='city', ylabel='Count'>

# %% [markdown]
# ***Baghdad is by far the most severely impacted city. This is most likely owing to the continuing conflict in Iraq and the existence of several terrorist organisations in the nation.Terrorist attacks have also had a substantial impact on Karachi, Lima, and Mosul. These cities are located in areas rife with violence and instability. There is a lot of data that does not belong to any city or the city name is not mentioned.***

# %% [markdown]
# ## Top 10 Attacking Methods used by terrorists

# %%
plt.subplots(figsize=(15,7))
sns.countplot(x='AttackType',data=df2,palette='inferno',order = df2['AttackType'].value_counts().index)
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# ## Top 10 Terrorists Group

# %%
group_count=df2['Group'].value_counts().sort_values(ascending=False).reset_index(name='count')

group_count_sorted1=group_count.iloc[1:]
group_count_sorted=group_count_sorted1.head(10)
plt.subplots(figsize=(12,7))
sns.barplot(y=group_count_sorted['count'],x=group_count_sorted['Group'],palette='inferno')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# ***The Taliban is a well-known terrorist group, but the global terrorism landscape is intricate. Several significant terrorist organizations, including ISIS, Al-Qaeda, Boko Haram, and Al-Shabaab, operate in different regions, making it challenging to definitively designate one as the "most active" worldwide. The prominence of these groups can shift over time.***

# %% [markdown]
# ## Top 10 years casualities wise

# %%
Total_Casualties=df2[['Year','Casualties']]
Total_Casualties1=Total_Casualties.groupby('Year').sum().reset_index()
Total_Casualties1.sort_values(by='Casualties',ascending=False,inplace=True)

sns.barplot(data=Total_Casualties1.head(10),x='Year',y='Casualties',order=Total_Casualties1['Year'].head(10))
# Out:
# <Axes: xlabel='Year', ylabel='Casualties'>

# %% [markdown]
# ``

# %% [markdown]
# ***We can clearly see that over the time the amount of casualties has increased which also indicates that the terrorist activities has also increased so far.***

# %% [markdown]
# ## Top 10 Motives for Attack

# %%
motive_data=df2[['eventid','Motive']]
motive_data=motive_data.groupby(by='Motive').count().reset_index()
motive_data_top10=motive_data.sort_values(by='eventid',ascending= False)[:10]
motive_data_top10
# Out:
#                                                   Motive  eventid
# 14279                                            Unknown    14889
# 6290      The specific motive for the attack is unknown.    14430
# 9128   The specific motive is unknown; however, sourc...      297
# 6292     The specific motive for the attack is unknown..      148
# 6277   The specific motive for the attack is unknown ...      144
# 6259       The specific motive for the attack is unknown       73
# 2308   Part of a campaign by Islamic extremists to de...       66
# 6659   The specific motive for the attack was political.       57
# 13004  The specific motive is unknown; however, sourc...       52
# 5102   The attack was carried out because the victim ...       50

# %%
group_data=df2['Group'].value_counts()
top_10_groups=df2[df2['Group'].isin(group_data[1:11].index)]

pd.crosstab(top_10_groups.Year,top_10_groups.Group).plot(color=sns.color_palette('Paired',10))
fig=plt.gcf()
fig.set_size_inches(16,6)

# %% [markdown]
# ## People Killed and Wounded in Each year

# %% [markdown]
# ## Total killed by Year

# %%
w=df2[['Year','killed','Wounded']].groupby('Year').sum()
plt.subplots(figsize=(10,7))
plt.xticks(rotation=80)
sns.barplot(data=w,x=w.index,y='killed',palette='inferno')
plt.title('Total Kills Through out Years')
# Out:
# Text(0.5, 1.0, 'Total Kills Through out Years')

# %% [markdown]
# ## Total Wounded by Year

# %%
plt.subplots(figsize=(10,7))
plt.xticks(rotation=80)
sns.barplot(data=w,x=w.index,y='Wounded',palette='inferno')
plt.title('Total Wounded Through out Years')
# Out:
# Text(0.5, 1.0, 'Total Wounded Through out Years')

# %% [markdown]
# ## Total Wounded and Killed People by Each Region

# %%
kw=df2[['Region','killed']].groupby('Region').sum().sort_values(by='killed',ascending=False)
kw
# Out:
#                                killed
# Region
# Middle East & North Africa   137642.0
# South Asia                   101319.0
# Sub-Saharan Africa            78386.0
# South America                 28849.0
# Central America & Caribbean   28708.0
# Southeast Asia                15637.0
# Eastern Europe                 7415.0
# Western Europe                 6694.0
# North America                  4916.0
# East Asia                      1152.0
# Central Asia                   1000.0
# Australasia & Oceania           150.0

# %%
wk=df2[['Region','Wounded']].groupby('Region').sum().sort_values(by='Wounded',ascending=False)
wk
# Out:
#                               Wounded
# Region
# Middle East & North Africa   214308.0
# South Asia                   141360.0
# Sub-Saharan Africa            52857.0
# Southeast Asia                26259.0
# North America                 21531.0
# Western Europe                18332.0
# South America                 16704.0
# Eastern Europe                12045.0
# East Asia                      9213.0
# Central America & Caribbean    8991.0
# Central Asia                   2009.0
# Australasia & Oceania           260.0

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#People Killed
kw.plot(kind="bar",color="indigo",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each Region")
ax0.set_xlabel("Regions")
ax0.set_ylabel("Number of People Killed")

#People Wounded
wk.plot(kind="bar",color="green",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each Region")
ax1.set_xlabel("Regions")
ax1.set_ylabel("Number of People Wounded")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Number of Casualties

# %%
casualties = df2[["Country","Casualties"]]
casualties=casualties.groupby("Country").sum().sort_values(by='Casualties',ascending= False).reset_index()
casualties["Percenatage"]=round((casualties["Casualties"]/casualties["Casualties"].sum())*100,2)

# %%
#Considerring only Top 15 countries
casualties15=casualties[:15]

# %%
plt.subplots(figsize=(15,7))
plt.title("Top 15 Countries Ranked by Number of Casualties")
plt.xticks(rotation = 75)
sns.barplot(x=casualties15.Country,y=casualties15.Percenatage,palette='inferno')
# For Data labels
for index, value in enumerate(casualties15['Percenatage']):
    plt.text(index, value, str(value), ha='center', va='bottom')

# %% [markdown]
# ***Countries like Iraq, Afganistan, Pakistan and India are more affected by Terrorism between 1970 to 2017. These countries account for more than 45% of all due to terrorism***

# %%
df2.columns
# Out:
# Index(['eventid', 'Year', 'Month', 'Day', 'Country', 'Region', 'State', 'city',
#        'latitude', 'longitude', 'AttackType', 'killed', 'Wounded', 'Target',
#        'Summary', 'Group', 'Target_type', 'Weapon_type', 'Motive', 'success',
#        'Casualties'],
#       dtype='object')

# %% [markdown]
# ## Terrorist Attacks in India

# %%
df2_India = df2[df2['Country']=='India']
Terrorist_group=df2_India['Group'].value_counts()[:10].reset_index(name='Count')
sns.barplot(x=Terrorist_group['Count'],y=Terrorist_group['Group'])
plt.title("Top 10 Terrorist Groups in India")
# Out:
# Text(0.5, 1.0, 'Top 10 Terrorist Groups in India')
